# %% [markdown]
# # Week 8: MCP Homework Questions 📝
# ## Challenge Yourself with These Exercises
#
# This notebook contains 4 homework exercises to deepen your understanding of MCP servers and clients.
#
# **Difficulty Levels:**
# - ⭐ Exercise 1: Easy (Extend existing code)
# - ⭐⭐ Exercise 2: Medium (Create new server)
# - ⭐⭐ Exercise 3: Medium (Mathematical operations)
# - ⭐⭐⭐ Challenge: Hard (Multi-tool integration)
#
# ---

# %% [markdown]
# # 📚 Exercise 1: Extend the Math Server ⭐
#
# ## Goal
# Add two new tools to your existing Math & Time Helper server:
# - `subtract_numbers(a, b)`: Subtract b from a
# - `divide_numbers(a, b)`: Divide a by b (handle division by zero)
#
# ## What You Need to Do
# 1. Open your `simple_server.py` file
# 2. Add the two new tools using the `@mcp.tool()` decorator
# 3. Update your `simple_client.py` to test both new tools
# 4. Run the client and verify the results
#
# ## Hints
# - Use the `@mcp.tool()` decorator just like you did for `add_numbers`
# - Add docstrings explaining what each function does
# - For `divide_numbers`, check if b equals 0 and raise a `ValueError`
# - Always use `file=sys.stderr` for logging
# - Test both functions by adding new `await session.call_tool()` calls in your client

# %% [markdown]
# ## Code Template for Exercise 1
#
# **Add these tools to your `simple_server.py`:**

# %%
# TODO: Add these two new tools to simple_server.py
# Remember to add them BEFORE the if __name__ == "__main__": line

# ===== NEW TOOL 1: subtract_numbers =====
# TODO: Add @mcp.tool() decorator
# TODO: Create function that takes two int parameters and returns int
# Hint: def subtract_numbers(a: int, b: int) -> int:
def subtract_numbers(a, b):
    # TODO: Add docstring
    # Hint: """Subtract b from a and return the result"""
    
    # TODO: Calculate result
    # Hint: result = a - b
    result = None  # REPLACE THIS
    
    # TODO: Log to stderr
    # Hint: print(f"subtract: {a} - {b} = {result}", file=sys.stderr)
    
    # TODO: Return result
    return result


# ===== NEW TOOL 2: divide_numbers =====
# TODO: Add @mcp.tool() decorator
# TODO: Create function that takes two float parameters and returns float
# Hint: def divide_numbers(a: float, b: float) -> float:
def divide_numbers(a, b):
    # TODO: Add docstring
    # Hint: """Safely divide a by b. Raises error if b is zero"""
    
    # TODO: Check if b is zero
    # Hint: if b == 0:
    #           raise ValueError("Cannot divide by zero!")
    
    # TODO: Calculate result
    # Hint: result = a / b
    result = None  # REPLACE THIS
    
    # TODO: Log to stderr
    # Hint: print(f"divide: {a} / {b} = {result}", file=sys.stderr)
    
    # TODO: Return result
    return result

# %% [markdown]
# ## Update Your Client for Exercise 1
#
# **Add these test calls to your `simple_client.py` after testing the existing tools:**

# %%
# TODO: Add these calls inside the run_client() function
# Place them after the get_current_time test, before print("All the test passed")

# ===== TEST NEW TOOL 1: subtract_numbers =====
# TODO: Uncomment and complete
# print("\nSubtraction tool check")
# result = await session.call_tool("___", arguments={"a": ___, "b": ___})
# print(f"Result: {result.content[0].text}")

# ===== TEST NEW TOOL 2: divide_numbers =====
# TODO: Uncomment and complete
# print("\nDivision tool check")
# result = await session.call_tool("___", arguments={"a": ___, "b": ___})
# print(f"Result: {result.content[0].text}")

# TODO: Test edge case - division by zero
# print("\nTesting division by zero error handling")
# try:
#     result = await session.call_tool("divide_numbers", arguments={"a": 10, "b": 0})
# except Exception as e:
#     print(f"Expected error caught: {e}")

# %% [markdown]
# ---
#
# # 🔤 Exercise 2: Build a String Manipulation Server ⭐⭐
#
# ## Goal
# Create a brand new server called `string_server.py` with three string tools:
# - `reverse_string(text)`: Returns the string reversed
# - `uppercase_string(text)`: Returns the string in UPPERCASE
# - `count_characters(text)`: Returns the number of characters
#
# ## What You Need to Do
# 1. Create a new file called `string_server.py` with all three tools
# 2. Create a corresponding client `string_client.py` to test the server
# 3. Run the client and verify all three tools work
#
# ## Hints
# - Use `%%writefile string_server.py` to create the file
# - Use `FastMCP("String Helper")` for the server name
# - For reversing: use Python slicing `text[::-1]`
# - For uppercase: use the `.upper()` method
# - For counting: use the `len()` function
# - All functions take a `str` parameter and return appropriate types
# - Remember `file=sys.stderr` for all logging!

# %%
# TODO: Create the string_server.py file
# Use %%writefile string_server.py at the start of your code

# %%writefile string_server.py
# ===== PART 1: Imports =====
# TODO: Import FastMCP and sys
# Hint: from mcp.server.fastmcp import FastMCP
# Hint: import sys

# ===== PART 2: Create Server =====
# TODO: Create server instance
# Hint: mcp = FastMCP("String Helper")

# ===== PART 3: Define Tool 1 - reverse_string =====
# TODO: Add @mcp.tool() decorator
# TODO: def reverse_string(text: str) -> str:
# Hints:
#   - Docstring: "Reverse a string and return it"
#   - Use slicing: text[::-1]
#   - Log: print(f"reverse_string: '{text}' -> '{result}'", file=sys.stderr)

# ===== PART 4: Define Tool 2 - uppercase_string =====
# TODO: Add @mcp.tool() decorator
# TODO: def uppercase_string(text: str) -> str:
# Hints:
#   - Docstring: "Convert string to UPPERCASE"
#   - Use .upper() method: text.upper()
#   - Log: print(f"uppercase_string: '{text}' -> '{result}'", file=sys.stderr)

# ===== PART 5: Define Tool 3 - count_characters =====
# TODO: Add @mcp.tool() decorator
# TODO: def count_characters(text: str) -> int:
# Hints:
#   - Docstring: "Count the number of characters in a string"
#   - Use len() function: len(text)
#   - Log: print(f"count_characters: '{text}' has {result} chars", file=sys.stderr)

# ===== PART 6: Run Server =====
# TODO: Add if __name__ == "__main__":
# TODO: Print startup message to stderr
# TODO: Call mcp.run()

# %%
# TODO: Create the string_client.py file to test the server
# Follow the same pattern as simple_client.py
# Use %%writefile string_client.py at the start

# Key changes:
# - Change server_script to "string_server.py"
# - Test all three tools:
#   1. reverse_string with a sample text
#   2. uppercase_string with a sample text
#   3. count_characters with a sample text

# Hints for testing:
# result = await session.call_tool("reverse_string", arguments={"text": "hello"})
# result = await session.call_tool("uppercase_string", arguments={"text": "hello"})
# result = await session.call_tool("count_characters", arguments={"text": "hello"})

# %% [markdown]
# ---
#
# # 🌡️ Exercise 3: Create a Temperature Conversion Server ⭐⭐
#
# ## Goal
# Build a `temperature_server.py` that converts between temperature scales:
# - `celsius_to_fahrenheit(celsius)`: Convert Celsius to Fahrenheit
# - `fahrenheit_to_celsius(fahrenheit)`: Convert Fahrenheit to Celsius
# - `celsius_to_kelvin(celsius)`: Convert Celsius to Kelvin
#
# ## What You Need to Do
# 1. Create `temperature_server.py` with the three conversion tools
# 2. Create `temperature_client.py` to test the conversions
# 3. Test with realistic temperature values
#
# ## Conversion Formulas
# - Celsius → Fahrenheit: `(celsius * 9/5) + 32`
# - Fahrenheit → Celsius: `(fahrenheit - 32) * 5/9`
# - Celsius → Kelvin: `celsius + 273.15`
#
# ## Hints
# - Use `%%writefile temperature_server.py`
# - Use `FastMCP("Temperature Converter")`
# - All functions take `float` parameters
# - All functions return `float`
# - Include formulas in docstrings for clarity
# - Test with known values:
#   - 0°C = 32°F = 273.15 K
#   - 100°C = 212°F = 373.15 K

# %%
# TODO: Create temperature_server.py
# Use %%writefile temperature_server.py

# %%writefile temperature_server.py
# ===== PART 1: Imports =====
# TODO: from mcp.server.fastmcp import FastMCP
# TODO: import sys

# ===== PART 2: Create Server =====
# TODO: mcp = FastMCP("Temperature Converter")

# ===== PART 3: Tool 1 - celsius_to_fahrenheit =====
# TODO: @mcp.tool()
# TODO: def celsius_to_fahrenheit(celsius: float) -> float:
# Hints:
#   - Formula in docstring: (celsius * 9/5) + 32
#   - result = (celsius * 9/5) + 32
#   - Log to stderr

# ===== PART 4: Tool 2 - fahrenheit_to_celsius =====
# TODO: @mcp.tool()
# TODO: def fahrenheit_to_celsius(fahrenheit: float) -> float:
# Hints:
#   - Formula in docstring: (fahrenheit - 32) * 5/9
#   - result = (fahrenheit - 32) * 5/9
#   - Log to stderr

# ===== PART 5: Tool 3 - celsius_to_kelvin =====
# TODO: @mcp.tool()
# TODO: def celsius_to_kelvin(celsius: float) -> float:
# Hints:
#   - Formula in docstring: celsius + 273.15
#   - result = celsius + 273.15
#   - Log to stderr

# ===== PART 6: Run Server =====
# TODO: if __name__ == "__main__":
# TODO: print("Starting Temperature Converter Server...", file=sys.stderr)
# TODO: mcp.run()

# %%
# TODO: Create temperature_client.py
# Use %%writefile temperature_client.py

# Test these conversions:
# 1. celsius_to_fahrenheit(0) should return 32.0
# 2. celsius_to_fahrenheit(100) should return 212.0
# 3. fahrenheit_to_celsius(32) should return 0.0
# 4. fahrenheit_to_celsius(212) should return 100.0
# 5. celsius_to_kelvin(0) should return 273.15
# 6. celsius_to_kelvin(100) should return 373.15

# Remember to:
# - Change server_script to "temperature_server.py"
# - Call all three conversion tools
# - Use await session.call_tool()

# %% [markdown]
# ---
#
# # 🧮 Challenge: Multi-Tool Integration Server ⭐⭐⭐
#
# ## Goal
# Create an advanced `calculator_server.py` with three mathematical tools:
# - `power(base, exponent)`: Calculate base raised to the power of exponent
# - `square_number(number)`: Calculate the square of a number
# - `absolute_value(number)`: Return the absolute value of a number
#
# ## What Makes This a Challenge
# - Comprehensive error handling and validation
# - Testing with edge cases (negative numbers, zero, large numbers)
# - Using multiple operations in a single client script
# - Complex test cases that verify tool robustness
#
# ## Hints
# - Use `%%writefile calculator_server.py`
# - Use `FastMCP("Advanced Calculator")`
# - For power: use `**` operator (e.g., `base ** exponent`)
# - For square: multiply the number by itself or use `**2`
# - For absolute value: use `abs()` built-in function
# - Accept `float` or `int` parameters
# - Return `float` from all functions
# - Test edge cases:
#   - Negative numbers
#   - Zero values
#   - Large exponents
#   - Decimal values

# %%
# TODO: Create calculator_server.py
# Use %%writefile calculator_server.py

# %%writefile calculator_server.py
# ===== PART 1: Imports =====
# TODO: from mcp.server.fastmcp import FastMCP
# TODO: import sys

# ===== PART 2: Create Server =====
# TODO: mcp = FastMCP("Advanced Calculator")

# ===== PART 3: Tool 1 - power =====
# TODO: @mcp.tool()
# TODO: def power(base: float, exponent: float) -> float:
# Hints:
#   - Docstring: "Calculate base raised to the power of exponent"
#   - Use: result = base ** exponent
#   - Log: print(f"power({base}, {exponent}) = {result}", file=sys.stderr)
#   - Return result

# ===== PART 4: Tool 2 - square_number =====
# TODO: @mcp.tool()
# TODO: def square_number(number: float) -> float:
# Hints:
#   - Docstring: "Calculate the square of a number"
#   - Use: result = number ** 2
#   - Log: print(f"square_number({number}) = {result}", file=sys.stderr)
#   - Return result

# ===== PART 5: Tool 3 - absolute_value =====
# TODO: @mcp.tool()
# TODO: def absolute_value(number: float) -> float:
# Hints:
#   - Docstring: "Return the absolute value of a number"
#   - Use: result = abs(number)
#   - Log: print(f"absolute_value({number}) = {result}", file=sys.stderr)
#   - Return result

# ===== PART 6: Run Server =====
# TODO: if __name__ == "__main__":
# TODO: print("Starting Advanced Calculator Server...", file=sys.stderr)
# TODO: mcp.run()

# %%
# TODO: Create calculator_client.py with comprehensive tests
# Use %%writefile calculator_client.py

# Test cases to verify:
# 1. power(2, 3) should return 8.0
# 2. power(2, 0) should return 1.0
# 3. power(10, -2) should return 0.01
# 4. square_number(5) should return 25.0
# 5. square_number(-5) should return 25.0
# 6. square_number(0) should return 0.0
# 7. absolute_value(-15) should return 15.0
# 8. absolute_value(15) should return 15.0
# 9. absolute_value(0) should return 0.0

# Remember:
# - Change server_script to "calculator_server.py"
# - Test ALL edge cases mentioned above
# - Use await session.call_tool() for each test
# - Verify the results match expected values
# - Print clear output for each test

# %% [markdown]
# ---
#
# # 📋 Submission Checklist
#
# Before submitting your homework, make sure you have:
#
# ## Exercise 1: Extended Math Server
# - [ ] Added `subtract_numbers` tool to `simple_server.py`
# - [ ] Added `divide_numbers` tool to `simple_server.py`
# - [ ] Updated `simple_client.py` to test both new tools
# - [ ] Tested division by zero error handling
# - [ ] Client successfully calls all 5 tools (add, multiply, time, subtract, divide)
#
# ## Exercise 2: String Manipulation Server
# - [ ] Created `string_server.py` with `FastMCP("String Helper")`
# - [ ] Implemented `reverse_string`, `uppercase_string`, `count_characters` tools
# - [ ] All tools have proper `@mcp.tool()` decorators and docstrings
# - [ ] Created `string_client.py` that tests all three tools
# - [ ] All logging uses `file=sys.stderr`
#
# ## Exercise 3: Temperature Conversion Server
# - [ ] Created `temperature_server.py` with `FastMCP("Temperature Converter")`
# - [ ] Implemented all three conversion tools with correct formulas
# - [ ] Created `temperature_client.py` that tests conversions
# - [ ] Tested with known conversion values (0°C = 32°F = 273.15 K)
# - [ ] All functions accept and return `float` types
#
# ## Challenge: Advanced Calculator
# - [ ] Created `calculator_server.py` with `FastMCP("Advanced Calculator")`
# - [ ] Implemented `power`, `square_number`, `absolute_value` tools
# - [ ] Created `calculator_client.py` with comprehensive edge case tests
# - [ ] Tested negative numbers, zero, and large exponents
# - [ ] All test cases pass and results are correct
#
# ---
#
# # 🎓 Learning Outcomes
#
# After completing these exercises, you should:
# - ✅ Understand how to extend existing MCP servers
# - ✅ Be able to create new servers from scratch
# - ✅ Know how to write proper tool functions with docstrings
# - ✅ Understand type hints and their importance
# - ✅ Be able to create comprehensive test clients
# - ✅ Know how to handle edge cases and errors in tools
# - ✅ Feel confident building real MCP applications
#
# ---
#
# # 💡 Tips for Success
#
# 1. **Start with Exercise 1** - It's the easiest and builds confidence
# 2. **Copy, don't memorize** - Copy the pattern from the session code
# 3. **Test frequently** - Run your client after each tool
# 4. **Read error messages** - They tell you what's wrong
# 5. **Use stderr for debugging** - Never use regular print() in tools!
# 6. **Type hints matter** - They're how AI agents understand your tools
# 7. **Docstrings are essential** - They describe what tools do
# 8. **Ask for help** - If stuck, review the main notebook
#
# ---
#
# **Good luck! 🚀**
