# %% [markdown]
# # Week 7: Customer Support Chatbot - Homework 🤖
#
# ## Instructions
# Answer the following 8 questions based on the concepts covered in Week 7. This homework focuses on:
# - RAG (Retrieval-Augmented Generation) architecture
# - Vector databases and embeddings
# - Conversation memory strategies
# - Prompt engineering for customer support
# - Metadata filtering and semantic search
#
# **Due Date**: End of Week 7
#
# ---

# %% [markdown]
# ## Question 1: Understanding RAG Architecture
#
# **Objective**: Explain the RAG pipeline in your own words
#
# ### Problem:
# In the Customer Support Chatbot project, we use a RAG (Retrieval-Augmented Generation) approach.
#
# **Task**:
# 1. Draw or describe the flow of a RAG system step-by-step (from user query to response)
# 2. Explain why RAG is better than a simple LLM for customer support FAQs
# 3. What are 3 advantages of using RAG in customer support scenarios?
#
# ### Your Answer:

# %% [markdown]
# ## Question 2: Vector Embeddings and Semantic Search
#
# **Objective**: Understand how embeddings enable semantic search
#
# ### Problem:
# A customer asks: "How do I change my account password?" but the FAQ says "How do I handle reset password?"
#
# **Task**:
# 1. Explain how embeddings would help match these two semantically similar questions
# 2. Why can't keyword matching (like Ctrl+F) solve this problem effectively?
# 3. If we had 500 FAQ items, how would a vector database help us find the best match efficiently?
#
# ### Your Answer:

# %% [markdown]
# ## Question 3: Chroma Vector Database
#
# **Objective**: Understand persistent vector storage
#
# ### Problem:
# In our project, we use Chroma as a persistent vector store for FAQ items.
#
# **Task**:
# 1. What does "persistent" storage mean? Why is it important for a chatbot?
# 2. How would you add 100 new FAQ items to an existing Chroma database without losing previous items?
# 3. Describe a scenario where you'd want to clear and recreate the Chroma database
#
# ### Your Answer:

# %% [markdown]
# ## Question 4: Metadata Filtering in Retrieval
#
# **Objective**: Apply metadata filtering to improve retrieval
#
# ### Problem:
# The FAQ dataset has metadata: `region` (US, EU, APAC, LATAM), `channel` (web app, mobile app, email, chat, phone), and `issue` (reset password, billing, etc.)
#
# **Task**:
# 1. A customer from the EU region asks about a reset password issue via the mobile app. How would you use metadata filtering to improve the retrieved results?
# 2. Write pseudocode or Python code that shows how to filter the retriever by region='EU' and channel='mobile app'
# 3. What could go wrong if a user query doesn't match any FAQs even after filtering?
#
# ### Your Answer:

# %% [markdown]
# ## Question 5: Conversation Memory Strategies
#
# **Objective**: Choose the right memory strategy for different scenarios
#
# ### Problem:
# We discussed three memory strategies in Week 7: Buffer Memory, Window Memory, and Summary Memory.
#
# **Task**:
# 1. A customer has a 50-message conversation with the chatbot. Which memory strategy would you use and why?
# 2. Compare Buffer Memory vs. Window Memory. When would you use one over the other?
# 3. What's the trade-off between keeping full conversation history (Buffer) and summarizing it (Summary Memory) in terms of cost and context quality?
# 4. Create a decision tree or table to help someone choose between the three memory types based on conversation length, budget, and quality requirements
#
# ### Your Answer:

# %% [markdown]
# ## Question 6: Prompt Engineering for Customer Support
#
# **Objective**: Craft effective system prompts
#
# ### Problem:
# You need to create a system prompt for the customer support chatbot that ensures it:
# - Only answers using the provided FAQ context
# - Escalates to human support when necessary
# - Maintains a professional, helpful tone
#
# **Task**:
# 1. Write a system prompt for the customer support chatbot (aim for 5-10 sentences)
# 2. How would you modify the prompt if you wanted the chatbot to be more casual/friendly vs. formal/professional?
# 3. What instructions would you add to handle cases where the FAQ doesn't have an answer?
#
# ### Your Answer:

# %% [markdown]
# ## Question 7: Building a Multi-Turn Conversation
#
# **Objective**: Implement context-aware multi-turn conversations
#
# ### Problem:
# Here's a conversation flow:
# ```
# User: I can't reset my password
# Bot: [Retrieves and provides reset password FAQ]
# User: I tried that but it still didn't work
# Bot: [Should understand context from previous message]
# User: Also, how do I contact support?
# Bot: [Should maintain memory of all 3 messages]
# ```
#
# **Task**:
# 1. Write Python code showing how you'd set up a conversation with memory using ConversationBufferMemory
# 2. How would the bot's response differ in message 2 vs. if memory wasn't being used?
# 3. What happens to the LLM token count as the conversation gets longer? How does this affect costs?
# 4. Suggest a solution if you notice token count becoming too expensive after 100+ turns
#
# ### Your Answer:

# %%
# Write your code here

# %% [markdown]
# ## Question 8: Production Deployment Considerations
#
# **Objective**: Think about real-world deployment challenges
#
# ### Problem:
# Your customer support chatbot is now being deployed to a production environment where:
# - It must handle 1000+ concurrent users
# - The FAQ database gets updated weekly
# - API costs matter (OpenAI embeddings + GPT-4)
# - Users expect <3 second response times
# - The chatbot must track which tickets need human escalation
#
# **Task**:
# 1. How would you cache embeddings to reduce API costs and improve speed?
# 2. Design a system to update the vector database weekly without downtime
# 3. What monitoring/logging would you implement to track chatbot performance and failures?
# 4. How would you ensure the chatbot can identify when to escalate to human support?
# 5. Describe your strategy for handling multiple concurrent conversations (1000 users at once)
#
# ### Your Answer:

# %% [markdown]
# ---
#
# ## Submission Guidelines
#
# 1. **Fill in your answers** for each question above
# 2. **Code cells** (Question 7) should be runnable if possible
# 3. **Be specific and detailed** - avoid one-word answers
# 4. **Show your thinking** - explain why you chose your answers
# 5. **Save this notebook** with your name: `Week7_Homework_[YourName].ipynb`
#
# ## Bonus Challenge 🌟
#
# Implement a small enhancement to the chatbot:
# - Add a new memory type (e.g., "Selective Memory" that only remembers key facts)
# - Create a custom metadata filter for region + issue type
# - Build a simple evaluation metric to measure chatbot accuracy
#
# Document your bonus work in a new cell below:

# %% [markdown]
# ## Bonus Challenge Answer
#
# *(Optional - only if you want to attempt this)*

# %%
# Write your bonus code here
