# %% [markdown]
# # WEEK5 — Retrieval Methods & Demos (Student Version)
#
# Headings + hint-only code cells to guide hands-on learning.

# %% [markdown]
# ## 1. TF-IDF (lexical retrieval)

# %%
# Hint: fit TfidfVectorizer and use cosine_similarity for retrieval
# Hint: show top-k document indices and short previews

# %% [markdown]
# ## 2. Dense retrieval (embeddings + FAISS)

# %%
# Hint: embed chunks, ensure dtype=float32 before adding to FAISS
# Hint: normalize vectors for cosine-like search; search top_k

# %% [markdown]
# ## 3. Hybrid retrieval (lexical + dense)

# %%
# Hint: compute TF-IDF scores and dense scores separately
# Hint: normalize each score array to [0,1] and fuse with weight alpha

# %% [markdown]
# ## 4. Re-ranking (Cross-Encoder or lightweight)

# %%
# Hint: collect candidate docs from hybrid retrieval
# Hint: use a CrossEncoder or a dot-product with SVD proxy to re-rank
# Hint: be mindful of model download time if using CrossEncoder

# %% [markdown]
# ## 5. Evaluation & Practical Tips

# %%
# Hint: measure recall@k for sample queries
# Hint: profile embedding time and search latency

# %% [markdown]
# ## Exercises:
# - Compare TF-IDF vs Dense retrieval on a few queries
# - Try hybrid fusion with different alpha values
