# %% [markdown]
# # Python File Execution Demo
#
# This notebook helps students understand how a `.py` file runs from the terminal.
#
# ## What students should learn
# - A Python script is a file that runs top to bottom
# - The terminal can execute the script with `python filename.py`
# - Small changes in the file change the output when you run it again

# %% [markdown]
# ## How to Run the Script
#
# In the terminal, go to this folder and run:
#
# ```bash
# python python_terminal_demo.py
# ```
#
# If Python is linked to a different version, use the full path to the interpreter from your virtual environment.

# %%
# 1) Greeting function
# Hint: return a string using an f-string

def greet(name):
    # TODO: return a welcome message
    pass

print(greet("Student"))

# %%
# 2) Variables and lists
# Hint: create a list of skills and print the first item

name = "Your Name"
age = 21
skills = ["Python", "Git", "GitHub"]

print(name)
print(age)
print(skills)
# TODO: print the first skill and total number of skills

# %%
# 3) Loop demo
# Hint: use enumerate to print numbered items

skills = ["Python", "Git", "GitHub"]

for item in skills:
    # TODO: print each item with a number
    pass

# %%
# 4) Grade function
# Hint: use if / elif / else

def grade(score):
    # TODO: return A, B, C, D, or F based on score
    pass

sample_scores = [95, 82, 67, 45, 20]
for score in sample_scores:
    print(score, "->", grade(score))

# %% [markdown]
# ## Live Session Prompts
#
# Use these while teaching:
# - Ask students what changed after editing the file
# - Ask them to re-run the script after each change
# - Ask them to compare notebook execution vs terminal execution
# - Ask them to try breaking the code and fixing it again
