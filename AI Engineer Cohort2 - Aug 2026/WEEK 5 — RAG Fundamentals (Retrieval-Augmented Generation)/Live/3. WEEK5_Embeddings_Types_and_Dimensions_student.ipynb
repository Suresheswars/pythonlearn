# %% [markdown]
# # WEEK5 — Embeddings: Types & Dimensions (Student Version)
#
# Hints-only code cells for hands-on exploration.

# %% [markdown]
# ## Introduction: why embeddings matter

# %%
# Hint: list embedding options (SBERT, OpenAI, TF-IDF) and tradeoffs
# Hint: demonstrate small examples to show vector dimensions

# %%
# Hint: define a small list of sample questions and a single sample text to embed in the demos below

# %% [markdown]
# Sentence Transformers:
# - all-mpnet-base-v2 ->
# - all-MiniLM-L6-v2 -> Small/ Fast/ Widely used for lightweight semantic search

# %% [markdown]
# ## SBERT (sentence-transformers)

# %%
# Hint: instantiate SentenceTransformer with a small model name
# Hint: call model.encode(['text1', 'text2']) and print shape

# %%
# Hint: check how many vectors were produced by SBERT (should match number of input texts)

# %% [markdown]
# ## OpenAI embeddings

# %%
# Hint: call OpenAI embeddings client and inspect returned vector length (e.g., 1536)
# Hint: ensure OPENAI_API_KEY is set before calling

# %% [markdown]
# ## TF-IDF (lexical) as a baseline vectorizer

# %%
# Hint: fit a TfidfVectorizer on documents and print feature dimension
# Hint: compare sparsity vs dense embeddings

# %% [markdown]
# ## Dimension discussion & exercises

# %%
# Hint: compare SBERT dim vs OpenAI dim; discuss downstream cost and index size
# Hint: try reducing dimension with TruncatedSVD and compare retrieval quality

# %% [markdown]
# 1. Sentence Transformers -> all-MiniLM-L6-v2
# 2. Sentence Transformers -> all-mpnet-base-v2

# %% [markdown]
# ## Exercises:
# - Compute embedding sizes for sample docs
# - Index and query small vectorstore to observe latency
